# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2025-10-28 05:51:49.768182: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761630709.999955      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761630710.061150      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
print(f'X_train shape: {x_train.shape}')
print(f'Y_train shape: {y_train.shape}')

print(f'X_test shape: {x_test.shape}')
print(f'Y_test shape: {y_test.shape}')
# Out:
# X_train shape: (50000, 32, 32, 3)
# Y_train shape: (50000, 1)
# X_test shape: (10000, 32, 32, 3)
# Y_test shape: (10000, 1)

# %%
label_dict = {
    0: "airplane",
    1: "automobile",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck"
}

# %%
y_train = np.squeeze(y_train)
y_test = np.squeeze(y_test)

# x_train = x_train[:, :, :, 0]
# x_test = x_test[:, :, :, 0]

# print(f'X_train shape: {x_train.shape}')
# print(f'Y_train shape: {y_train.shape}')

# print(f'X_test shape: {x_test.shape}')
# print(f'Y_test shape: {y_test.shape}')

# %%
plt.figure(figsize = (8,8))
n = 4

for i in range(n * n):
  plt.subplot(n, n, i + 1)
  random_idx = np.random.randint(0, x_train.shape[0])
  plt.imshow(x_train[random_idx], cmap = 'gray')
  plt.title(f'{label_dict[y_train[random_idx]]}')
  plt.xticks([])
  plt.yticks([])
plt.tight_layout()

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

x_train_norm = x_train / 255
x_test_norm = x_test / 255

# %%
# change input size

x_expanded= np.array([np.flip(img, axis=1) for img in x_train_norm])

x_train_norm = np.concatenate([x_train_norm, x_expanded], axis=0)
y_train = np.concatenate([y_train, y_train], axis=0)

print(f'X_train shape: {x_train_norm.shape}')
print(f'Y_train shape: {y_train.shape}')

print(f'X_test shape: {x_test.shape}')
print(f'Y_test shape: {y_test.shape}')
# Out:
# X_train shape: (100000, 32, 32, 3)
# Y_train shape: (100000, 10)
# X_test shape: (10000, 32, 32, 3)
# Y_test shape: (10000, 10)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, load_model

# %%
model = Sequential([
    
    Conv2D(64, (3,3), activation = 'relu', input_shape = (32, 32, 3)), # number of filters, filter size, activation
    BatchNormalization(),
    Conv2D(64, (3,3), activation = 'relu', padding="same"),
    BatchNormalization(),
    MaxPooling2D((2, 2)), #always end conv block with a max pool layer

    Dropout(0.25),

    Conv2D(64, (3,3), activation = 'relu', padding="same"),
    BatchNormalization(),
    Conv2D(64, (3,3), activation = 'relu', padding="same"),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Dropout(0.25),

    Conv2D(64, (3,3), activation = 'relu', padding="same"),
    BatchNormalization(),
    Conv2D(64, (3,3), activation = 'relu', padding="same"),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Dropout(0.25),

    Flatten(),
    Dense(32, activation = 'relu'),
    Dropout(0.25),
    Dense(10, activation = 'softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1761630737.090805      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy', #cross entropy used for classification
    metrics = ['accuracy'],
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 30, 30, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 15, 15, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 15, 15, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 15, 15, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 15, 15, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 7, 7, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 7, 7, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 206,762 (807.66 KB)
#  Trainable params: 205,994 (804.66 KB)
#  Non-trainable params: 768 (3.00 KB)

# %%
train_history = model.fit(x_train_norm, y_train, validation_data = (x_test_norm, y_test), epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761630748.387760      60 service.cc:148] XLA service 0x7dfe74003260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761630748.388856      60 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1761630749.060644      60 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   30/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - accuracy: 0.1379 - loss: 2.8803
# I0000 00:00:1761630754.011473      60 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 31s 6ms/step - accuracy: 0.3648 - loss: 1.7322 - val_accuracy: 0.5135 - val_loss: 1.4845
# Epoch 2/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.6506 - loss: 1.0077 - val_accuracy: 0.7387 - val_loss: 0.7644
# Epoch 3/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.7265 - loss: 0.8083 - val_accuracy: 0.7295 - val_loss: 0.8150
# Epoch 4/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.7602 - loss: 0.7107 - val_accuracy: 0.7974 - val_loss: 0.5936
# Epoch 5/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.7843 - loss: 0.6428 - val_accuracy: 0.7978 - val_loss: 0.6045
# Epoch 6/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8012 - loss: 0.6002 - val_accuracy: 0.8055 - val_loss: 0.5751
# Epoch 7/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8113 - loss: 0.5684 - val_accuracy: 0.8293 - val_loss: 0.5063
# Epoch 8/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8224 - loss: 0.5331 - val_accuracy: 0.8235 - val_loss: 0.5173
# Epoch 9/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8295 - loss: 0.5149 - val_accuracy: 0.8382 - val_loss: 0.4843
# Epoch 10/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8351 - loss: 0.4928 - val_accuracy: 0.8430 - val_loss: 0.4822
# Epoch 11/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8386 - loss: 0.4859 - val_accuracy: 0.8394 - val_loss: 0.4909
# Epoch 12/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8448 - loss: 0.4603 - val_accuracy: 0.8455 - val_loss: 0.4601
# Epoch 13/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8533 - loss: 0.4445 - val_accuracy: 0.8489 - val_loss: 0.4620
# Epoch 14/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8568 - loss: 0.4316 - val_accuracy: 0.8546 - val_loss: 0.4379
# Epoch 15/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8602 - loss: 0.4225 - val_accuracy: 0.8607 - val_loss: 0.4193
# Epoch 16/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8626 - loss: 0.4114 - val_accuracy: 0.8447 - val_loss: 0.4669
# Epoch 17/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8649 - loss: 0.4065 - val_accuracy: 0.8615 - val_loss: 0.4220
# Epoch 18/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8674 - loss: 0.3989 - val_accuracy: 0.8517 - val_loss: 0.4440
# Epoch 19/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8701 - loss: 0.3859 - val_accuracy: 0.8644 - val_loss: 0.4179
# Epoch 20/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8712 - loss: 0.3836 - val_accuracy: 0.8656 - val_loss: 0.4096
# Epoch 21/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8734 - loss: 0.3803 - val_accuracy: 0.8665 - val_loss: 0.4196
# Epoch 22/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8778 - loss: 0.3663 - val_accuracy: 0.8730 - val_loss: 0.3893
# Epoch 23/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8773 - loss: 0.3671 - val_accuracy: 0.8637 - val_loss: 0.4275
# Epoch 24/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8812 - loss: 0.3572 - val_accuracy: 0.8611 - val_loss: 0.4252
# Epoch 25/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8808 - loss: 0.3565 - val_accuracy: 0.8639 - val_loss: 0.4254
# Epoch 26/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8823 - loss: 0.3513 - val_accuracy: 0.8720 - val_loss: 0.3948
# Epoch 27/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8854 - loss: 0.3448 - val_accuracy: 0.8723 - val_loss: 0.4088
# Epoch 28/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8829 - loss: 0.3456 - val_accuracy: 0.8726 - val_loss: 0.4011
# Epoch 29/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8906 - loss: 0.3313 - val_accuracy: 0.8746 - val_loss: 0.3995
# Epoch 30/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8882 - loss: 0.3306 - val_accuracy: 0.8755 - val_loss: 0.3969
# Epoch 31/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8895 - loss: 0.3233 - val_accuracy: 0.8735 - val_loss: 0.3881
# Epoch 32/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8912 - loss: 0.3245 - val_accuracy: 0.8790 - val_loss: 0.3808
# Epoch 33/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8935 - loss: 0.3179 - val_accuracy: 0.8785 - val_loss: 0.3826
# Epoch 34/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8940 - loss: 0.3146 - val_accuracy: 0.8796 - val_loss: 0.3762
# Epoch 35/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8988 - loss: 0.3060 - val_accuracy: 0.8693 - val_loss: 0.4177
# Epoch 36/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8939 - loss: 0.3136 - val_accuracy: 0.8713 - val_loss: 0.4034
# Epoch 37/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8995 - loss: 0.2990 - val_accuracy: 0.8690 - val_loss: 0.3944
# Epoch 38/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8972 - loss: 0.3070 - val_accuracy: 0.8831 - val_loss: 0.3734
# Epoch 39/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8986 - loss: 0.3002 - val_accuracy: 0.8689 - val_loss: 0.4280
# Epoch 40/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9001 - loss: 0.2943 - val_accuracy: 0.8870 - val_loss: 0.3696
# Epoch 41/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9006 - loss: 0.2961 - val_accuracy: 0.8817 - val_loss: 0.3808
# Epoch 42/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9012 - loss: 0.2968 - val_accuracy: 0.8803 - val_loss: 0.3904
# Epoch 43/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9024 - loss: 0.2907 - val_accuracy: 0.8786 - val_loss: 0.3849
# Epoch 44/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9021 - loss: 0.2897 - val_accuracy: 0.8790 - val_loss: 0.3869
# Epoch 45/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9031 - loss: 0.2887 - val_accuracy: 0.8911 - val_loss: 0.3572
# Epoch 46/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9040 - loss: 0.2825 - val_accuracy: 0.8861 - val_loss: 0.3696
# Epoch 47/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9077 - loss: 0.2768 - val_accuracy: 0.8846 - val_loss: 0.3821
# Epoch 48/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9053 - loss: 0.2809 - val_accuracy: 0.8876 - val_loss: 0.3710
# Epoch 49/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9043 - loss: 0.2803 - val_accuracy: 0.8772 - val_loss: 0.4044
# Epoch 50/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9081 - loss: 0.2730 - val_accuracy: 0.8847 - val_loss: 0.3743
# Epoch 51/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9077 - loss: 0.2696 - val_accuracy: 0.8817 - val_loss: 0.3906
# Epoch 52/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9088 - loss: 0.2710 - val_accuracy: 0.8876 - val_loss: 0.3697
# Epoch 53/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9108 - loss: 0.2674 - val_accuracy: 0.8850 - val_loss: 0.4020
# Epoch 54/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9094 - loss: 0.2685 - val_accuracy: 0.8857 - val_loss: 0.3690
# Epoch 55/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9115 - loss: 0.2635 - val_accuracy: 0.8816 - val_loss: 0.3829
# Epoch 56/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9110 - loss: 0.2630 - val_accuracy: 0.8849 - val_loss: 0.3709
# Epoch 57/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9111 - loss: 0.2646 - val_accuracy: 0.8819 - val_loss: 0.4036
# Epoch 58/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9145 - loss: 0.2560 - val_accuracy: 0.8859 - val_loss: 0.3728
# Epoch 59/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9137 - loss: 0.2576 - val_accuracy: 0.8860 - val_loss: 0.3727
# Epoch 60/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9118 - loss: 0.2603 - val_accuracy: 0.8760 - val_loss: 0.4108
# Epoch 61/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9110 - loss: 0.2619 - val_accuracy: 0.8883 - val_loss: 0.3637
# Epoch 62/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9127 - loss: 0.2570 - val_accuracy: 0.8867 - val_loss: 0.3797
# Epoch 63/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9129 - loss: 0.2523 - val_accuracy: 0.8869 - val_loss: 0.3674
# Epoch 64/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9131 - loss: 0.2559 - val_accuracy: 0.8870 - val_loss: 0.3767
# Epoch 65/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9147 - loss: 0.2517 - val_accuracy: 0.8773 - val_loss: 0.4138
# Epoch 66/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9171 - loss: 0.2461 - val_accuracy: 0.8884 - val_loss: 0.3602
# Epoch 67/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9166 - loss: 0.2486 - val_accuracy: 0.8936 - val_loss: 0.3677
# Epoch 68/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9178 - loss: 0.2445 - val_accuracy: 0.8892 - val_loss: 0.3674
# Epoch 69/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9179 - loss: 0.2462 - val_accuracy: 0.8918 - val_loss: 0.3648
# Epoch 70/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9164 - loss: 0.2457 - val_accuracy: 0.8893 - val_loss: 0.3634
# Epoch 71/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9177 - loss: 0.2448 - val_accuracy: 0.8913 - val_loss: 0.3564
# Epoch 72/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9189 - loss: 0.2408 - val_accuracy: 0.8868 - val_loss: 0.3582
# Epoch 73/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9192 - loss: 0.2367 - val_accuracy: 0.8904 - val_loss: 0.3610
# Epoch 74/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9182 - loss: 0.2398 - val_accuracy: 0.8890 - val_loss: 0.3719
# Epoch 75/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9190 - loss: 0.2363 - val_accuracy: 0.8912 - val_loss: 0.3604
# Epoch 76/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9206 - loss: 0.2374 - val_accuracy: 0.8860 - val_loss: 0.3775
# Epoch 77/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9232 - loss: 0.2277 - val_accuracy: 0.8870 - val_loss: 0.3795
# Epoch 78/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9228 - loss: 0.2278 - val_accuracy: 0.8904 - val_loss: 0.3768
# Epoch 79/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9230 - loss: 0.2259 - val_accuracy: 0.8881 - val_loss: 0.3815
# Epoch 80/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9214 - loss: 0.2323 - val_accuracy: 0.8788 - val_loss: 0.4171
# Epoch 81/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9212 - loss: 0.2318 - val_accuracy: 0.8889 - val_loss: 0.3904
# Epoch 82/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9214 - loss: 0.2303 - val_accuracy: 0.8876 - val_loss: 0.3950
# Epoch 83/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9218 - loss: 0.2318 - val_accuracy: 0.8903 - val_loss: 0.3818
# Epoch 84/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9226 - loss: 0.2310 - val_accuracy: 0.8904 - val_loss: 0.3763
# Epoch 85/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9246 - loss: 0.2249 - val_accuracy: 0.8901 - val_loss: 0.3861
# Epoch 86/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9238 - loss: 0.2252 - val_accuracy: 0.8921 - val_loss: 0.3866
# Epoch 87/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9226 - loss: 0.2286 - val_accuracy: 0.8967 - val_loss: 0.3550
# Epoch 88/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9235 - loss: 0.2211 - val_accuracy: 0.8930 - val_loss: 0.3798
# Epoch 89/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9256 - loss: 0.2238 - val_accuracy: 0.8920 - val_loss: 0.3698
# Epoch 90/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9262 - loss: 0.2193 - val_accuracy: 0.8930 - val_loss: 0.3794
# Epoch 91/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9250 - loss: 0.2209 - val_accuracy: 0.8924 - val_loss: 0.3692
# Epoch 92/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9265 - loss: 0.2207 - val_accuracy: 0.8857 - val_loss: 0.3917
# Epoch 93/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - accuracy: 0.9248 - loss: 0.2229 - val_accuracy: 0.8863 - val_loss: 0.3988
# Epoch 94/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9246 - loss: 0.2197 - val_accuracy: 0.8816 - val_loss: 0.4123
# Epoch 95/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9243 - loss: 0.2194 - val_accuracy: 0.8897 - val_loss: 0.3837
# Epoch 96/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9268 - loss: 0.2178 - val_accuracy: 0.8917 - val_loss: 0.3703
# Epoch 97/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9291 - loss: 0.2092 - val_accuracy: 0.8876 - val_loss: 0.3902
# Epoch 98/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9272 - loss: 0.2153 - val_accuracy: 0.8945 - val_loss: 0.3837
# Epoch 99/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9276 - loss: 0.2119 - val_accuracy: 0.8940 - val_loss: 0.3670
# Epoch 100/100
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9255 - loss: 0.2149 - val_accuracy: 0.8841 - val_loss: 0.3942

# %%
plt.plot(train_history.history['accuracy'], label = 'Train accuracy')
plt.plot(train_history.history['val_accuracy'], label = 'Val accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(alpha = 0.2)
plt.savefig("graph.png")
plt.show()


plt.plot(train_history.history['loss'], label = 'Train loss')
plt.plot(train_history.history['val_loss'], label = 'Val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(alpha = 0.2)
plt.savefig("graph2.png")
plt.show()

# %%
print(y_test.shape)
y_test = np.argmax(y_test, axis=1)
# Out:
# (10000, 10)

# %%
y_pred = model.predict(x_test_norm)
y_pred = np.argmax(y_pred, axis=-1)

test_accuracy = np.mean(y_pred == y_test)
print(test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# 0.8841

# %%
from sklearn.metrics import classification_report

true_classes = y_test

print("Classification Report:")
print(classification_report(true_classes, y_pred, 
                          target_names=list(label_dict.values()), digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane     0.7993    0.9560    0.8707      1000
#   automobile     0.9402    0.9430    0.9416      1000
#         bird     0.8902    0.8110    0.8488      1000
#          cat     0.8329    0.7130    0.7683      1000
#         deer     0.8991    0.8820    0.8905      1000
#          dog     0.7933    0.8790    0.8340      1000
#         frog     0.8958    0.9370    0.9159      1000
#        horse     0.9370    0.8920    0.9139      1000
#         ship     0.9401    0.9100    0.9248      1000
#        truck     0.9377    0.9180    0.9277      1000
#
#     accuracy                         0.8841     10000
#    macro avg     0.8866    0.8841    0.8836     10000
# weighted avg     0.8866    0.8841    0.8836     10000

# %%
per_class_acc = [(y_pred[y_test == i] == i).mean() 
                 for i in range(len(label_dict))]

print("per-class Accuracy:")
for class_name, accuracy in zip(label_dict.values(), per_class_acc):
    print(f"{class_name:>10}: {accuracy:.4f}")
# Out:
# per-class Accuracy:
#   airplane: 0.9560
# automobile: 0.9430
#       bird: 0.8110
#        cat: 0.7130
#       deer: 0.8820
#        dog: 0.8790
#       frog: 0.9370
#      horse: 0.8920
#       ship: 0.9100
#      truck: 0.9180

# %%
plt.figure(figsize = (15,15))
n = 4

for i in range(n * n):
    plt.subplot(n, n, i + 1)
    random_idx = np.random.randint(0, x_test.shape[0])
    plt.imshow(x_test[random_idx], cmap = 'gray')
    plt.title(f'pred: {label_dict[y_pred[random_idx]]} - true: {label_dict[y_test[random_idx]]}')
    plt.xticks([])
    plt.yticks([])

plt.savefig("result_imgs.png")

# %%
plt.savefig("result_imgs.png")
